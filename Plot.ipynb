# %% [markdown]
# # CIFAR-10

# %% [markdown]
# # 4000labels-model 1

# %% [markdown]
# 4000 labels - 10 epochs Model 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
vgg16 = [0.8338,0.5535,0.5426,0.4709,0.4592,0.5797,0.2474,0.4574,0.2417,0.2192]
resnet50 = [0.8718,0.7223,0.6182,0.6391,0.4674,0.4192,0.3939,0.3689,0.3697,0.3498]
shake_wrn = [0.3185,0.2929,0.2626,0.2603,0.2447,0.2291,0.2214,0.2183,0.2078,0.1959]
nin = [0.3489,0.3377,0.3064,0.4581,0.2658,0.2735,0.2462,0.2176,0.2126,0.1651]
wrn = [0.3241,0.2729,0.2208,0.3142,0.3350,0.2529,0.2073,0.2207,0.1947,0.1448]
convnet = [0.3240,0.3327,0.2804,0.2672,0.2748,0.2056,0.2334,0.2330,0.2206,0.1340]
df=pd.DataFrame({'x': range(1,11), 'VGG16': vgg16, 'ResNet50': resnet50, 'shake_wrn': shake_wrn, 'NIN': nin, 'wrn':wrn, 'convnet': convnet})
# multiple line plot
plt.plot( 'x', 'VGG16', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'ResNet50', data=df, marker='o', markerfacecolor='blue',markersize=3, color='sienna',linewidth=2)
plt.plot( 'x', 'shake_wrn', data=df, marker='o',markerfacecolor='blue',markersize=3, color='coral', linewidth=2)
plt.plot( 'x', 'NIN', data=df, marker='o', markerfacecolor='blue', markersize=3, color='lightgreen',linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='gold', linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='*', markerfacecolor='blue', markersize=3, color='purple',linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-4000 labels')
plt.grid(True)
plt.savefig('./Pics/cifar10-4000-10_epochs.png')

# %% [markdown]
# 4000 labels - 10epochs Model 1 + Affine & Move proxy labels + kld

# %%
convnet = [0.6214,0.3541,0.2464,0.3365,0.2129,0.3099,0.2254,0.2765,0.1856,0.1411]
shake_wrn = [0.3454,0.2716,0.2644,0.2513,0.2465,0.2463,0.2234,0.2188,0.2238,0.2010]
wrn = [0.3498,0.2874,0.2023,0.3455,0.2185,0.2897,0.2930,0.2098,0.2447,0.1433]

# %% [markdown]
# 4000 labels - 10epochs Model 1 + Affine & Move proxy labels

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
convnet = [0.2551,0.3934,0.3240,0.3360,0.3114,0.4256,0.2032,0.2803,0.2333,0.1748]
wrn = [0.3087,0.2903,0.2766,0.3983,0.2157,0.2875,0.1869,0.2769,0.1960,0.1386]
shake_wrn = [0.3250,0.2687,0.2686,0.2555,0.2478,0.2342,0.2172,0.2168,0.2123,0.2033]
nin = [0.3812,0.3243,0.3449,0.3185,0.2776,0.2562,0.2568,0.2969,0.3421,0.1633]
df=pd.DataFrame({'x': range(1,11), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet,'nin':nin})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.plot( 'x', 'nin', data=df, marker='o',markerfacecolor='blue',markersize=3, color='gold', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-Affine&Translation-1000-10 labels')
plt.grid(True)
plt.savefig('./Pics/cifar10-Affine&Translation-1000-10_epochs.png')

# %% [markdown]
# # 1000labels -model 1

# %% [markdown]
# 1000 labels - 10epochs Model 1

# %%
convnet= [0.4327,0.4142,0.3467,0.3222,0.4044,0.3439,0.3045,0.3739,0.2710,0.2053]
wrn = [0.5157,0.4328,0.3480,0.4671,0.4236,0.3655,0.2405,0.3098,0.2381,0.2017]
shake_wrn = [0.4337,0.3926,0.3643,0.3887,0.3669,0.3550,0.3320,0.3367,0.3218,0.2983]
nin = [0.4795,0.4759,0.5238,0.4052,0.3969,0.3899,0.3890,0.3462,0.3283,0.2437]
df=pd.DataFrame({'x': range(1,11), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet,'nin':nin})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.plot( 'x', 'nin', data=df, marker='o',markerfacecolor='blue',markersize=3, color='gold', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-1000-10 labels')
plt.grid(True)
plt.savefig('./Pics/cifar10-1000-10_epochs.png')

# %% [markdown]
# 1000 labels - 20 epochs Model 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
wrn = [0.4750,0.3976,0.3787,0.3336,0.3639,0.3357,0.3091,0.3563,0.2963,0.3290,0.4245,0.3490,0.2641,0.2528,0.2530,0.2246,0.2364,0.2542,0.2198,0.1872]
convnet = [0.4692,0.3200,0.4897,0.5350,0.3219,0.3709,0.3503,0.4557,0.3399,0.3631,0.3123,0.3174,0.3077,0.2711,0.2968,0.2541,0.2586,0.2354,0.2243,0.1845]
shake_wrn = [0.4363,0.3892,0.3739,0.3687,0.3737,0.3732,0.3641,0.3385,0.3312,0.3285,0.3467,0.3426,0.3071,0.3295,0.3081,0.3021,0.3065,0.2944,0.2784,0.2771]
nin = [0.5781,0.5309,0.4503,0.4938,0.4176,0.3907,0.3714,0.3607,0.4940,0.3591,0.3175,0.3389,0.3437,0.3213,0.3124,0.3205,0.2947,0.2888,0.2742,0.2343]
df=pd.DataFrame({'x': range(1,21), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet,'nin':nin})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.plot( 'x', 'nin', data=df, marker='o',markerfacecolor='blue',markersize=3, color='gold', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-1000-20 labels')
plt.grid(True)
plt.savefig('./Pics/cifar10-1000-20_epochs.png')

# %% [markdown]
# 1000 labels - 30 epochs Model 1

# %%
convnet = [0.4808,0.4479,0.4479,0.4198,0.4732,0.4421,0.4304,0.3612,0.4348,0.2780,0.5934,0.3606,]

# %% [markdown]
# 1000 labels -- 20 epochs + 128 bz + color-300

# %%
convnet = [0.5546,0.6365,0.3973,0.3737,0.4227,0.4043,0.4339,0.3423,0.3449,0.4108,0.4542,0.4719,0.3655,0.3358,0.2739,0.3165,0.2856,0.3023,0.2866,0.2075]
wrn =     [0.5848,0.5101,0.3682,0.7191,0.4675,0.4208,0.4206,0.4202,0.4069,0.4567,0.3151,0.4276,0.4699,0.4158,0.4041,0.4392,0.4631,0.4474,0.4856,0.4272]
shake_wrn =[0.4084,0.3879,0.3877,0.3990,0.3737,0.3924,0.3723,0.3760,0.3726,0.3439,0.3542,0.3420,0.3398,0.3584,0.3506,0.3240,0.3334,0.3219,0.3231,0.2999]

# %% [markdown]
# 1000 labels -- 20 epochs + 128 bz + color-200

# %%
convnet = ？[0.6462,0.6244,0.4230,0.4555,0.4466,0.5459,0.3842,0.4920,0.5413,0.4735,0.4711,0.4455,0.4360,0.3910,0.4550,0.4666,0.5841,0.4584,0.4004,0.4207]
          [0.5721,0.5706,0.4984,0.4246,0.4509,0.4841,0.5177,0.4287,0.5317,0.3500,0.2853,0.4973,0.4657,0.4550,0.2803,0.3808,0.5299,0.4590,0.4673,0.4126]
wrn =      [0.5344,0.4825,0.5763,0.5409,0.3751,0.4629,0.4110,0.3652,0.4222,0.4814,0.4146,0.3911,0.4415,0.4462,0.3327,0.4251,0.4126,0.4723,0.4076,0.4125]
shake_wrn = [0.4478,0.4010,0.4066,0.3833,0.3775,0.3426,0.3590,0.3471,0.3592,0.3557,0.3503,0.3354,0.3279,0.3430,0.3322,0.3144,0.3085,0.3161,0.3024,0.2936]

# %% [markdown]
# 1000 labels -- 20 epochs + 128 bz + color-100

# %%
convnet = [0.5640,0.4638,0.4874,0.4169,0.3638,0.5257,0.3862,0.4982,0.4139,0.5143,0.3080,0.5413,0.3803,0.4723,0.3259,0.3927,0.4280,0.5170,0.4251,0.3327]
wrn = ? [0.4833,0.5078,0.4971,0.4973,0.4029,0.4367,0.3467,0.4090,0.4606,0.4814,0.3983,0.4928,0.4522,0.4687,0.4413,0.4215,0.4456,0.4829,0.4501,0.4254]
        [0.6122,0.5374,0.4942,0.4811,0.3431,0.3518,0.5306,0.4761,0.4193,0.4923,0.4040,0.4024,0.4218,0.4711,0.3801,0.4854,0.4181,0.4327,0.4238,0.4351]
shake_wrn = [0.4704,0.4157,0.3886,0.3819,0.3708,0.3706,0.3646,0.3519,0.4202,0.3479,0.3623,0.3442,0.3377,0.3428,0.3511,0.3399,0.3243,0.3198,0.3138,0.3072]

# %% [markdown]
# 1000 labels -- 30 epochs + 128 bz + color-100

# %%
convnet =? [0.5294,0.5442,0.5307,0.4181,0.3901,0.6775,0.4811,0.6043,0.4291,0.3254,0.4407,0.4022,0.4594,0.3513,0.4280,0.5387,0.4921,0.4922,0.4915,0.4042,0.4322,0.5658,0.4769,0.6156,0.5965,0.6382,0.5615,0.5461,0.5855,0.6558]

# %% [markdown]
# 1000 labels -- 30 epochs + 128 bz + color-100（cifar100)

# %%
convnet = [0.6450,0.5229,0.4781,0.3937,0.3774,0.5427,0.3595,0.4667,0.3489,0.4178,0.3038,0.4341,0.4282,0.3702,0.3777,0.3139,0.3794,0.3184,0.3157,0.3247,0.3217,0.2428,0.3216,0.2707,0.3093,0.2744,0.2467,0.2787,0.2248,0.2033]
wrn = []
shake_wrn=[]

# %% [markdown]
# 1000 labels -- 20 epochs + 128 bz + color-100（cifar100)

# %%
convnet =? [0.5926,0.4964,0.3892,0.4410,0.5321,0.5727,0.5432,0.4740,0.4882,0.3531,0.5776,0.5344,0.4245,0.3799,0.4848,0.4637,0.4375,0.5624,0.5465,0.4608]

# %% [markdown]
# # 2000labels

# %% [markdown]
# 2000 labels - 10 epochs Model 1

# %%
wrn = [0.3893,0.4096,0.3475,0.3365,0.2537,0.2453,0.2702,0.2268,0.2380,0.1766]
convnet = [0.2980,0.3945,0.3742,0.2793,0.3113,0.3290,0.3168,0.2937,0.2565,0.1615]
shake_wrn = [0.3565,0.3436,0.3135,0.3063,0.3082,0.2971,0.2843,0.2945,0.2638,0.2573]
nin = [0.4663,0.4416,0.3885,0.3714,0.4131,0.3753,0.3908,0.2506,0.2869,0.2049]
resnet50 = [0.8778,0.8577,0.7635,0.7188,0.5359,0.4419,0.4345,0.4216,0.4068,0.3969]
vgg16 =    [0.7311,0.4341,0.4465,0.4893,0.8825,0.8996,0.7695,0.8994,0.8797,0.8816]

# %% [markdown]
# 2000 labels - 20 epochs Model 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
wrn = [0.4646,0.3202,0.3267,0.3335,0.3081,0.2699,0.2868,0.2853,0.2790,0.2526,0.2724,0.2640,0.3173,0.2498,0.2640,0.2550,0.2252,0.2083,0.1828,0.1611]
convnet = [0.5581,0.3217,0.4830,0.4123,0.3622,0.3812,0.3410,0.3317,0.2796,0.2566,0.2781,0.2674,0.2216,0.2502,0.2123,0.2294,0.2327,0.2837,0.1871,0.1527]
shake_wrn = [0.3838,0.3424,0.3212,0.3182,0.3059,0.2996,0.2837,0.3090,0.2788,0.2999,0.2688,0.2668,0.2704,0.2777,0.2723,0.2452,0.2538,0.2469,0.2388,0.2300]
nin = [0.4586,0.3080,0.3308,0.3720,0.2907,0.4105,0.3601,0.3239,0.3636,0.3066,0.2857,0.2847,0.3202,0.2865,0.2928,0.2671,0.2564,0.2427,0.2243,0.1859]
df=pd.DataFrame({'x': range(1,21), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet,'nin':nin})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.plot( 'x', 'nin', data=df, marker='o',markerfacecolor='blue',markersize=3, color='gold', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-2000 labels')
plt.grid(True)

# %% [markdown]
# 2000 labels -- 20 epochs + 128 bz + color-100

# %%
wrn = [0.4509,0.4254,0.4275,0.3424,0.4242,0.3738,0.2994,0.3045,0.4366,0.3463,0.4059,0.3049,0.3188,0.2664,0.2620,0.3327,0.2936,0.4050,0.3421,0.2878]?
convnet = [0.3319,0.3978,0.4211,0.2942,0.4365,0.2884,0.4661,0.3975,0.2842,0.3080,0.2663,0.3352,0.2820,0.2396,0.2315,0.2642,0.2797,0.2059,0.2108,0.1624]
shake_wrn = [0.3624,0.3376,0.3304,0.3309,0.3242,0.3218,0.2870,0.2925,0.2903,0.2961,0.2742,0.2857,0.3030,0.2751,0.2721,0.2992,0.2760,0.2634,0.2708,0.2456]

# %% [markdown]
# 2000 labels -- 20 epochs + 128 bz + color-300

# %%
wrn =      [0.4302,0.4105,0.3223,0.3821,0.3326,0.3956,0.3640,0.3084,0.4246,0.2858,0.2980,0.3657,0.3587,0.2831,0.3393,0.3011,0.3151,0.2920,0.2941,0.3242]
convnet =  [0.3481,0.3384,0.3286,0.3225,0.2768,0.3530,0.2924,0.3289,0.3551,0.2417,0.2938,0.3038,0.2768,0.2585,0.2491,0.2549,0.2805,0.1990,0.2221,0.1652]
shake_wrn =[0.3733,0.3297,0.3294,0.3223,0.2964,0.3266,0.3213,0.3082,0.2860,0.3166,0.3152,0.2812,0.3027,0.2884,0.2723,0.2875,0.2848,0.2670,0.2596,0.2462]

# %% [markdown]
# 2000 labels -- 20 epochs + 128 bz + color-200

# %%
convnet =   [0.3370,0.3499,0.3037,0.3686,0.3978,0.3499,0.2766,0.2884,0.3111,0.2594,0.2719,0.3637,0.2727,0.2452,0.2497,0.2171,0.2249,0.2508,0.2015,0.1674]
wrn =       [0.5501,0.3378,0.4806,0.3098,0.4440,0.3051,0.4605,0.3261,0.3636,0.3776,0.3713,0.2948,0.4118,0.3639,0.3099,0.3319,0.4294,0.2840,0.2955,0.2693]
shake_wrn = [0.3917,0.3326,0.3186,0.3107,0.3009,0.2924,0.3171,0.2887,0.2952,0.2964,0.2943,0.2768,0.2892,0.2845,0.2751,0.2674,0.2612,0.2707,0.2478,0.2373]

# %% [markdown]
# 2000 labels -- 30 epochs + 128 bz + color-100

# %%
convnet = [0.4467,0.3497,0.4035,0.3212,0.3467,0.2731,0.4038,0.3516,0.3423,0.3426,0.3320,0.3131,0.2536,0.3033,0.3100,0.2699,0.2433,0.2715,0.2509,0.3044,0.2396,0.2395,0.2205,0.2366,0.2137,0.2465,0.1993,0.1957,0.1911,0.1622]
wrn =? [0.4372,0.3089,0.3474,0.2960,0.4027,0.4141,0.3530,0.3445,0.3575,0.3196,0.3460,0.3238,0.3526,0.3179,0.3895,0.3582,0.3944,0.4053,0.2767,0.3258,0.5390,0.4403,0.4085,0.2979,0.3403,0.4881,0.3952,0.4061,0.4878,0.4116]
shake_wrn = [,0.4170,0.3711,0.3337,0.3529,0.3293,0.3186,0.3335,0.3239,0.3246,0.3247,0.3032,0.3026,0.3130,0.2884,0.2892,0.3139,0.3080,0.2832,0.2745,0.2967,0.2914,0.2706,0.2815,0.2796,0.2811,0.2775,0.2738,0.2700,0.2521,0.2524]

# %% [markdown]
# 2000 labels -- 20 epochs + 128 bz + color-100（cifar100)

# %%
convnet = []

# %% [markdown]
# # 4000 labels

# %% [markdown]
# 4000 labels -- 20 epochs

# %%
wrn = [0.3443,0.3402,0.2376,0.2869,0.2285,0.1953,0.2426,0.1965,0.2561,0.2301,0.1939,0.2098,0.2054,0.1748,0.2147,0.1802,0.1878,0.1714,0.1617,0.1254]
convnet = [0.3169,0.3083,0.2901,0.3065,0.3603,0.2725,0.3000,0.2411,0.2702,0.1827,0.1882,0.2275,0.3331,0.2039,0.2531,0.1973,0.1584,0.1511,0.1539,0.1257]
shake_wrn = [0.3566,0.2832,0.2929,0.2494,0.2506,0.2293,0.2405,0.2339,0.2162,0.2127,0.2116,0.2135,0.2070,0.2049,0.1919,0.1965,0.1849,0.1862,0.1717,0.1657]
nin = [0.3566,0.3204,0.4789,0.3507,0.3874,0.2339,0.2675,0.2233,0.2422,0.2526,0.2567,0.2556,0.2484,0.2482,0.2443,0.2099,0.2219,0.2379,0.2049,0.1536]
df=pd.DataFrame({'x': range(1,21), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet,'nin':nin})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.plot( 'x', 'nin', data=df, marker='o',markerfacecolor='blue',markersize=3, color='gold', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-4000 labels')
plt.grid(True)

# %% [markdown]
# 4000 labels --  20 epochs + 128 bz + color-100

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
wrn = [0.2843, 0.3642,0.3202,0.2974,0.2511,0.2864,0.2603,0.2958,0.2374,0.2078, 0.2015,0.2544,0.2463,0.1803,0.2053, 0.2153,0.1915,0.1753,0.1463,0.1297]
shake_wrn = [0.3359,0.2802,0.2584,0.2747,0.2608,0.2577,0.2338,0.2371,0.2216,0.2227,0.2097,0.2105,0.2248,0.2016,0.2101,0.1998,0.1938,0.1967,0.1912,0.1758]
convnet = [0.4402,0.3725,0.3257,0.2887,0.2596,0.2208,0.2402,0.2178,0.2612,0.2316,0.2059,0.1945,0.2307,0.2225,0.2157,0.2127,0.1807,0.1707,0.1724,0.1301]
"0.3086,0.4247,0.3432,0.2874,0.2797,0.2591,0.2248,0.3044,0.2026,0.2185,0.1991,0.2627,0.2228,0.2082,0.1901,0.2231,0.1936,0.1885,0.1600,0.1304"
df=pd.DataFrame({'x': range(1,21), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-4000_labels-20-color+100')
plt.grid(True)
plt.savefig('./Pics/CIFAR10-4000_labels-20-color+100.png')

# %% [markdown]
# 4000 labels -- 30 epochs + 128 bz + color-100

# %%
shake_wrn = [0.3339,0.2731,0.2850,0.2444,0.2486,0.2494,0.2375,0.2294,0.2233,0.2296,0.2113,0.2097,0.1986,0.2041,0.1945,0.2134,0.2057,0.2028,0.1986,0.1877,0.1963,0.1804,0.1742,0.1861,0.1899,0.1804,0.1724,0.1740,0.1680,0.1565]
wrn = [0.3557,0.2986,0.2499,0.3551,0.2691,0.2984,0.3215,0.2888,0.4279,0.2539,0.2871,0.2849,0.2738,0.2754,0.2750,0.2332,0.2451,0.2844,0.3048,0.2865,0.2818,0.2291,0.2269,0.2659,0.2506,0.2521,0.2234,0.2409,0.2595,0.2148]
convnet = [0.3396,0.2686,0.3082,0.3077,0.2532,0.2229,0.2621,0.2187,0.3553,0.2392,0.2205,0.1825,0.2043,0.2059,0.2918,0.2267,0.2181,0.2480,0.1806,0.2474,0.2133,0.2054,0.2128,0.1968,0.2055,0.1809,0.1730,0.1587,0.1546,0.1305]
df=pd.DataFrame({'x': range(1,31), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-4000_labels-30-color+100')
plt.grid(True)
plt.savefig('./Pics/CIFAR10-4000_labels-30-color+100.png')

# %% [markdown]
# 4000 labels -- 20 epochs + 128 bz + color-300

# %%
convnet = [0.4148,0.2332,0.2469,0.2790,0.2747,0.2549,0.2694,0.2546,0.2334,0.2790,0.2320,0.2174,0.3017,0.2542,0.1918,0.2284,0.1864,0.2383,0.2248,0.2012,0.2640,0.1662,0.1840,0.1970,0.2746,0.2240,0.1666,0.1522,0.1530,0.1282]
wrn = [0.5198,0.3820,0.4488,0.3125,0.3445,0.3038,0.3182,0.2800,0.3830,0.2932,0.3046,0.2624,0.2308,0.2574,0.2830,0.2781,0.2803,0.2864,0.2349,0.2894,0.3001,0.2183,0.3061,0.2103,0.2582,0.2847,0.2108,0.2420,0.1969,0.1744]
shake_wrn = [0.3250,0.2924,0.2679,0.2686,0.2531,0.2402,0.2511,0.2611,0.2412,0.2486,0.2194,0.2702,0.2154,0.2080,0.2252,0.2085,0.2196,0.2003,0.2301,0.1933,0.2291,0.2019,0.1789,0.1749,0.1821,0.1774,0.1903,0.1718,0.1722,0.1601]
df=pd.DataFrame({'x': range(1,31), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('CIFAR10-4000_labels-30-color+300')
plt.grid(True)
plt.savefig('./Pics/CIFAR10-4000_labels-30-color+300.png')

# %% [markdown]
# 4000 labels -- 30 epochs + 128 bz + color(100) --100

# %%
convnet = [0.3607,0.3615,0.2412,0.3350,0.2485,0.3057,0.2180,0.2473,0.2598,0.1974,0.2125,0.2444,0.2650,0.2083,0.2385,0.2018,0.2212,0.1992,0.2349,0.1873,0.1849,0.1681,0.2421,0.1981,0.1905,0.1662,0.1600,0.1760,0.1413,0.1262]
wrn = []
shake_wrn = []

# %% [markdown]
# 4000 labels -- 20 epochs + 128 bz + color-300 seed = 5

# %%
convnet = [0.3975,0.3969,0.2442,0.3745,0.2561,0.2790,0.2641,0.2815,0.2314,0.1995,0.2704,0.3021,0.2225,0.2075,0.2133,0.2067,0.1893,0.1648,0.1620,0.1313]
          [0.3893,0.3257,0.3013,0.3134,0.2279,0.2914,0.3888,0.3840,0.2329,0.2853,0.2783,0.2597,0.2546,0.2846,0.2807,0.2709,0.2730,0.2515,0.2525,0.2746]
shake_wrn = [0.3670,0.3322,0.2836,0.2529,0.2446,0.2585,0.2378,0.2490,0.2343,0.2529,0.2350,0.2332,0.2383,0.2095,0.2191,0.2045,0.1938,0.1985,0.2035,0.1780]
wrn = [0.3202,0.3146,0.2101,0.2754,0.3136,0.2834,0.2752,0.2461,0.3005,0.3165,0.2527,0.1978,0.2126,0.2001,0.1919,0.2068,0.2093,0.1820,0.2233,0.1755]

# %% [markdown]
# 4000 labels -- 20 epochs + 128 bz + color-300 seed = 10

# %%
shake_wrn = [0.3341,0.2817,0.2768,0.2440,0.2491,0.2550,0.2377,0.2374,0.2279,0.2238,0.2111,0.2069,0.1940,0.2115,0.2050,0.1977,0.1854,0.1780,0.1852,0.1681]
convnet = [0.3411,0.3111,0.2657,0.2567,0.3749,0.2879,0.2461,0.2477,0.2724,0.2143,0.3140,0.2131,0.2363,0.2843,0.2313,0.1749,0.2693,0.2462,0.1684,0.2173]
wrn = [0.3493,0.2620,0.2705,0.2849,0.3035,0.2921,0.2811,0.3202,0.2495,0.2692,0.3115,0.2105,0.2735,0.2850,0.2278,0.2706,0.2718,0.2121,0.1871,0.2366]

# %% [markdown]
# 4000 labels -- 20 epochs + 128 bz + color-300 seed = 15

# %%
shake_wrn = [0.3353,0.2757,0.2617,0.2862,0.2608,0.2322,0.2349,0.2204,0.2243,0.2323,0.2156,0.2315,0.2113,0.1993,0.2003,0.1968,0.1859,0.1862,0.1911,0.1734]
convnet = [0.3580,0.3198,0.3844,0.3593,0.3017,0.3976,0.3559,0.2846,0.3010,0.2807,0.2420,0.2695,0.3009,0.2614,0.2760,0.2600,0.2858,0.2832,0.3032,0.2648]
wrn = [0.3783,0.3052,0.3679,0.3537,0.4320,0.3787,0.3722,0.2450,0.2674,0.3197,0.2698,0.2837,0.3524,0.2995,0.3115,0.2621,0.2929,0.2393,0.2456,0.2243]

# %% [markdown]
# # 50000

# %% [markdown]
# 50000 labels--10 epochs Model1 -- bz=128

# %%
convnet = [0.2358,0.2399,0.2421,0.1380,0.1490,0.1389,0.1201,0.1060,0.0925,0.0642]
shake_wrn = [0.3099,0.2321,0.1859,0.1667,0.1453,0.1266,0.1285,0.1086,0.1049,0.0898]
ResNet50 = [0.8945,0.7328,0.4385,0.3529,0.6590,0.4431,0.3247,0.4083,0.2792,0.3034]
vgg16 = [0.6733,0.4000,0.2754,0.1780,0.1606,0.1167,0.1233,0.1078,0.0932,0.0884]
nin = [0.3458,0.2540,0.2292,0.2252,0.1628,0.2340,0.1766,0.1207,0.1431,0.0803]
wrn = [0.2550,0.1936,0.1823,0.2052,0.1444,0.1463,0.1429,0.1007,0.0861,0.0596]

# %% [markdown]
# 50000 labels--20 epochs Model1 --bz=128

# %%
convnet = [0.2782,0.1628,0.2760,0.2005,0.1530,0.1703,0.1821,0.1767,0.1557,0.1067,0.1290,0.1197,0.1433,0.0904,0.1409,0.1159,0.0842,0.0858,0.0702,0.0487]
vgg16 = [0.5300,0.2611,0.1543,0.1276,0.1084,0.1024,0.0980,0.1103,0.0939,0.0849,0.0847,0.0890,0.0812,0.0854,0.0831,0.0904,0.0872,0.0788,0.0744,0.0737]
shake_wrn = [0.3308,0.2644,0.1875,0.1747,0.1666,0.1516,0.1328,0.1180,0.1171,0.1116,0.1253,0.1066,0.1169,0.1006,0.1275,0.0974,0.0955,0.0965,0.0833,0.0751]
resnet50 = [0.7770,0.5880,0.6025,0.8934,0.4746,0.4168,0.4132,0.4047,0.4060,0.7458,0.5251,0.4584,0.4104,0.3597,0.3475,0.3358,0.3271,0.3119,0.2984,0.2934]
nin = [0.3026,0.2396,0.2241,0.2101,0.2044,0.2436,0.1599,0.1472,0.1838,0.1834,0.1352,0.1436,0.1240,0.1233,0.1191,0.1356,0.1152,0.0997,0.0960,0.0653]
wrn = [0.2584,0.2098,0.2214,0.1276,0.1475,0.1918,0.1236,0.1108,0.1367,0.1380,0.1077,0.1140,0.1217,0.1365,0.1209,0.1150,0.1012,0.0866,0.0775,0.0558]

# %% [markdown]
# 50000 labels--20 epochs Model2 --bz=128--100

# %%
convnet = [0.2137,0.3040,0.1697,0.1434,0.1361,0.1341,0.1259,0.1157,0.1130,0.1317,0.1281,0.0978,0.1405,0.1093,0.1080,0.1230,0.0847,0.1025,0.0680,0.0495]
shake_wrn = [0.3641,0.2833,0.1952,0.1758,0.1481,0.1272,0.1391,0.1273,0.1161,0.1138,0.1058,0.1056,0.0976,0.0969,0.0940,0.0960,0.1045,0.0855,0.0762,0.0697]
wrn = [0.2948,0.1643,0.2072,0.2164,0.1935,0.1940,0.1512,0.1739,0.1549,0.1450,0.1278,0.1701,0.1298,0.1380,0.1037,0.1209,0.1075,0.1186,0.0924,0.0673]

# %% [markdown]
# 50000 labels--20 epochs Model2 --bz=128--300

# %%
wrn =      [0.3313,0.3765,0.1840,0.1957,0.2190,0.1492,0.1603,0.1445,0.1414,0.1774,0.1675,0.1403,0.1987,0.1226,0.1251,0.1151,0.1390,0.1813,0.0940,0.0712]
shake_wrn =[0.3122,0.2581,0.2103,0.1637,0.1511,0.1475,0.1216,0.1283,0.1109,0.1115,0.1060,0.0962,0.0971,0.0915,0.0899,0.1014,0.0890,0.0876,0.0741,0.0658]
convnet =  [0.2391,0.1968,0.2244,0.1473,0.1259,0.1202,0.2181,0.1261,0.1158,0.1102,0.1009,0.1037,0.1137,0.1060,0.0843,0.1071,0.0738,0.1135,0.0650,0.0513]

# %% [markdown]
# 50000 labels--20 epochs Model2 --bz=128--200

# %%
shake_wrn = [0.2919,0.2904,0.1913,0.1698,0.1421,0.1350,0.1318,0.1410,0.1055,0.1113,0.1022,0.0961,0.1085,0.1027,0.0977,0.0931,0.0986,0.0873,0.0776,0.0690]
wrn =       [0.2642,0.1893,0.2203,0.2223,0.2272,0.1783,0.1655,0.1401,0.1379,0.1185,0.1267,0.1606,0.1272,0.1481,0.1163,0.1907,0.1130,0.1202,0.0924,0.0705]
convnet =   [0.2741,0.2672,0.3235,0.2179,0.1889,0.1076,0.1466,0.1939,0.1068,0.1320,0.1406,0.1021,0.1007,0.2064,0.0920,0.1063,0.0851,0.0870,0.0691,0.0514]

# %% [markdown]
# # SVHN

# %% [markdown]
# # 73257labels

# %% [markdown]
# 73257 labels -- 10 epochs Model 1

# %%
vgg16 = [0.0698,0.0459,0.0516,0.0516,0.0436,0.0445,0.0399,0.0425,0.0393,0.0373]
convnet = [0.0552,0.0480,0.0447,0.0376,0.0391,0.0585,0.0410,0.0355,0.0374,0.0267]
shake_wrn = [0.0512,0.0491,0.0449,0.0408,0.0361,0.0373,0.0368,0.0324,0.0303,0.0290]
ResNet50 = [0.5656,0.1484,0.7973,0.1808,0.1600,0.2017,0.1457,0.1160,0.1036,0.0950]
wrn = [0.0917,0.0570,0.0484,0.0577,0.0406,0.0512,0.0428,0.0399,0.0425,0.0260]

# %% [markdown]
# 73257 labels + 30epochs + color + 100 -- 30 epochs Model 2

# %%
shake_wrn = [0.0611,0.0476,0.0509,0.0450,0.0680,0.0532,0.0801,0.0773,0.0629,0.0631,0.0560,0.0731,0.0696,0.0671,0.0623,0.0685,0.1105,0.0654,0.0815,0.0718,0.0693,0.0717,0.0897,0.0742,0.0723,0.0704,0.0905,0.0706,0.0799,0.0812]
wrn = ？ [0.0933,0.0836,0.0987,0.0666,0.0746,0.0731,0.0917,0.0833,0.0755,0.0842,0.1129,0.0635,0.0908,0.0707,0.0463,0.0626,0.0826,0.2044,0.1409,0.0952,0.0583,0.1055,0.0879,0.0647,0.0833,0.1046,0.1386,0.1575,0.1696,0.1243]
convnet = [0.0618,0.0399,0.0413,0.0535,0.0364,0.0427,0.0451,0.0375,0.0414,0.0350,0.0478,0.0395,0.0439,0.0416,0.0390,0.0407,0.0469,0.0471,0.0394,0.0355,0.0435,0.0388,0.0373,0.0360,0.0339,0.0333,0.0306,0.0344,0.0274,0.0251]

# %% [markdown]
# 73257 labels + 30epochs + color + 300 -- 30 epochs Model 2

# %%
shake_wrn = [0.1222,0.1074,0.0817,0.0878,0.0763,0.0705,0.0865,0.0927,0.0636,0.0742,0.0713,0.0724,0.0736,0.0697,0.0616,0.0829,0.0749,0.0714,0.0658,0.0593,0.0586,0.0639,0.0564,0.0760,0.0609,0.0620,0.0661,0.0729,0.0544,0.0571]
wrn =     [0.0601,0.0379,0.0541,0.0455,0.0371,0.0423,0.0468,0.0388,0.0481,0.0439,0.0493,0.0402,0.0521,0.0419,0.0369,0.0412,0.0473,0.0702,0.0415,0.0584,0.0450,0.0352,0.0497,0.0425,0.0669,0.0425,0.0465,0.0928,0.0345,0.0331]
convnet = [0.0529,0.0418,0.0438,0.0582,0.0405,0.0396,0.0476,0.0695,0.0397,0.0372,0.0491,0.0419,0.0377,0.0352,0.0395,0.0384,0.0406,0.0401,0.0377,0.0369,0.4118,0.0418,0.0340,0.0382,0.0385,0.0356,0.0299,0.0372,0.0265,0.0263]

# %% [markdown]
# 73257 labels + 30epochs + color + 200 -- 30 epochs Model 2

# %%
shake_wrn = [0.0521,0.0489,0.0429,0.0333,0.0357,0.0390,0.0381,0.0324,0.0322,0.0325,0.0361,0.0317,0.0327,0.0337,0.0313,0.0312,0.0308,0.0351,0.0380,0.0322,0.0314,0.0335,0.0317,0.0260,0.0275,0.0272,0.0272,0.0259,0.0280,0.0234]
wrn =  [0.0657,0.0744,0.0555,0.1021,0.0648,0.0850,0.0652,0.0778,0.0762,0.0870,0.0897,0.0802,0.0989,0.0899,0.0470,0.0663,0.0486,0.0447,0.0370,0.0361,0.0773,0.0461,0.0469,0.1498,0.0371,0.0359,0.0352,0.0333,0.1798,0.0242]
convnet =[0.0594,0.0527,0.0684,0.0742,0.0409,0.0352,0.0480,0.0371,0.0439,0.0351,0.0472,0.0428,0.0464,0.0373,0.0396,0.0374,0.0404,0.0423,0.0412,0.0372,0.0409,0.0399,0.0370,0.3405,0.0359,0.0342,0.0315,0.0325,0.0297,0.0257]

# %% [markdown]
# # 1000labels

# %% [markdown]
# 1000 labels - 30epochs Model 1 + Affine & Move proxy labels

# %%
shake_wrn = [0.0550,0.0519,0.0504,0.0546,0.0531,0.0572,0.0666,0.0566,0.0756,0.0639,0.0876,0.0727,0.0746,0.0701,0.0971,0.0824,0.0888,0.0999,0.0941,0.0973,0.1062,0.0895,0.0894,0.1106,0.1033,0.1230,0.1071,0.1015,0.1298,0.1080]
wrn =       [0.0550,0.0519,0.0504,0.0546,0.0531,0.0572,0.0666,0.0566,0.0756,0.0639,0.0876,0.0727,0.0746,0.0701,0.0971,0.0824,0.0888,0.0999,0.0941,0.0973,0.1062,0.0895,0.0894,0.1106,0.1033,0.1230,0.1071,0.1015,0.1298,0.1080]
convnet =   [0.0805,0.0431,0.0439,0.0572,0.0409,0.0396,0.0490,0.0486,0.0356,0.0394,0.0410,0.0379,0.0385,0.0376,0.0371,0.0397,0.0433,0.0443,0.0532,0.0357,0.0384,0.0388,0.0375,0.0421,0.0388,0.0356,0.0360,0.0306,0.0317,0.0260]
ResNet50 =  [0.1964,0.6274,0.2423,0.2134,0.1453,0.1291,0.1120,0.1055,0.1056,0.0920,0.0878,0.0849,0.0880,0.0909,0.0839,0.0799,0.0749,0.0752,0.0812,0.0801,0.0743,0.0780,0.0736,0.0826,0.0827,0.0695,0.0781,0.0772,0.0714,0.0867]
vgg16 =     [0.1541,0.1116,0.0649,0.0590,0.0633,0.0599,0.0640,0.0560,0.1726,0.0871,0.0691,0.0582,0.0595,0.0604,0.0530,0.0444,0.0510,0.0568,0.0597,0.0510,0.0532,0.0425,0.0418,0.0606,0.0554,0.0524,0.0537,0.0523,0.0428,0.0512]

# %% [markdown]
# 1000labels -- 30 epochs

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
convnet = [0.1957,0.1069,0.1252,0.1497,0.1076,0.0944,0.1185,0.1581,0.1054,0.1386,0.1069,0.0887,0.0973,0.1027,0.1285,0.0888,0.1232,0.0940,0.1139,0.0923,0.1017,0.0965,0.0840,0.0762,0.0862,0.0869,0.0834,0.0872,0.0795,0.0656]
nin = [0.1987,0.1883,0.1648,0.1874,0.1865,0.1382,0.1359,0.1490,0.1207,0.1361,0.1229,0.1322,0.1222,0.1437,0.1774,0.1436,0.1424,0.1499,0.1658,0.1756,0.1900,0.1451,0.1343,0.1479,0.1565,0.2100,0.2298,0.1827,0.1446,0.0854]
shake_wrn = [0.1028,0.0893,0.1034,0.0923,0.0867,0.0647,0.0744,0.0754,0.0779,0.0863,
       0.0648,0.0789,0.0859,0.0761,0.0644,0.0647,0.0679,0.0592,0.0757,0.0716,
      0.0652,0.0660,0.0667,0.0671,0.0609,0.0610,0.0572,0.0522,0.0591,0.0494]
wrn = [0.1770,0.2195,0.1088,0.1180,0.1228,0.0972,0.1147,0.1083,0.0973,0.1128,
      0.1048,0.1119,0.0951,0.1029,0.0873,0.1540,0.0931,0.1053,0.1444,0.1102,
      0.1054,0.0902,0.0796,0.0918,0.0832,0.0968,0.0827,0.0935,0.0734,0.0734]
df=pd.DataFrame({'x': range(1,31), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet,'nin':nin})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.plot( 'x', 'nin', data=df, marker='o',markerfacecolor='blue',markersize=3, color='gold', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('SVHN-1000_labels')
plt.grid(True)
plt.savefig('./Pics/svhn-1000-30_epochs.png')

# %% [markdown]
# 1000 labels --- 12 epochs

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
convnet = [0.1897,0.1575,0.1431,0.1245,0.1759,0.1204,0.1290,0.1100,0.1085,0.1151,0.0901,0.0827]
wrn = [0.1693,0.1332,0.1359,0.1530,0.1373,0.1653,0.1041,0.1187,0.1258,0.0931,0.0786,0.0678]
shake_wrn =[0.0924,0.0809,0.0753,0.0828,0.0775,0.0661,0.0728,0.0689,0.0683,0.0648,0.0632,0.0550]

# %% [markdown]
# 1000 labels --- 30 epochs ---Colorize-200 epochs

# %%
shake_wrn = [0.1407,0.1052,0.0859,0.0851,0.0853,0.0778,0.1008,0.0968,0.0861,0.0700,0.0779,0.0773,0.0862,0.0769,0.0723,0.0941,0.0960,0.1024,0.0771,0.0784,0.0857,0.0749,0.0877,0.0635,0.0799,0.0780,0.0717,0.0901,0.0772,0.0719]
wrn =       [0.2049,0.1267,0.1598,0.1293,0.2087,0.1962,0.2051,0.3906,0.3578,0.3128,0.1399,0.2968,0.1107,0.3349,0.3950,0.1875,0.2083,0.2581,0.0948,0.3420,0.2979,0.3171,0.3590,0.3556,0.2635,0.0758,0.3669,0.2980,0.3090,0.0599]
convnet =   [0.1970,0.1557,0.2075,0.1124,0.1754,0.1410,0.2140,0.1097,0.1248,0.1229,0.1165,0.1180,0.1182,0.1264,0.1204,0.0884,0.1020,0.0902,0.1011,0.3315,0.1140,0.1124,0.1008,0.0960,0.0909,0.0865,0.0952,0.0867,0.0855,0.0730]

# %% [markdown]
# 1000 labels --- 30 epochs ---Colorize-100 epochs -- seed = 1

# %%
convnet = [0.1745,0.2754,0.1447,0.1650,0.1759,0.1598,0.1242,0.1268,0.1340,0.2326,0.1664,0.1697,0.2963,0.0866,0.1178,0.1144,0.1232,0.0872,0.1112,0.1002,0.1110,0.0860,0.0970,0.1131,0.0832,0.0950,0.0842,0.1000,0.0965,0.0736]
shake_wrn = [0.1156,0.0967,0.0878,0.0816,0.0708,0.0702,0.0804,0.0840,0.0744,0.0728,0.0829,0.0829,0.0732,0.0727,0.0724,0.0768,0.0724,0.0757,0.0633,0.0678,0.0629,0.0733,0.0746,0.0587,0.0561,0.0632,0.0592,0.0651,0.0547,0.0496]
wrn = [0.1822,0.1340,0.2883,0.1690,0.1745,0.1001,0.1252,0.1370,0.1900,0.2481,0.3912,0.3985,0.4465,0.3140,0.2594,0.1059,0.0863,0.3858,0.0971,0.1137,0.2296,0.2677,0.2818,0.1292,0.1479,0.0813,0.2447,0.0837,0.3126,0.2199]
df=pd.DataFrame({'x': range(1,31), 'shake_wrn': shake_wrn, 'wrn':wrn, 'convnet': convnet})
plt.plot( 'x', 'shake_wrn', data=df, marker='o', markerfacecolor='blue', markersize=3, color='skyblue', linewidth=2)
plt.plot( 'x', 'wrn', data=df, marker='o', markerfacecolor='blue',markersize=3, color='pink',linewidth=2)
plt.plot( 'x', 'convnet', data=df, marker='o',markerfacecolor='blue',markersize=3, color='yellowgreen', linewidth=2)
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.title('SVHN-1000_labels-30-color+100')
plt.grid(True)
plt.savefig('./Pics/SVHN-1000_labels-30-color+100.png')

# %% [markdown]
# 1000 labels --- 30 epochs ---Colorize-300 epochs -- seed = 5

# %%
shake_wrn = [,0.1087,0.1072,0.0990,0.0782,0.0839,0.0801,0.0853,0.0748,0.0877,0.0700,0.0794,0.0724,0.0771,0.0698,0.0676,0.0736,0.0695,0.0661,0.0703,0.0590,0.0691,0.0674,0.0744,0.0618,0.0740,0.0602,0.0698,0.0542,0.0596,0.0505]
wrn =？ [,0.1726,0.2211,0.1638,0.2316,0.3140,0.2020,0.2213,0.2985,0.2404,0.1346,0.1729,0.0840,0.2198,0.3374,0.2397,0.4941,0.4462,0.3737,0.3646,0.3632,0.4033,0.5451,0.1313,0.2224,0.1472,0.3220,0.2774,0.3324,0.2867,0.2493]
convnet = [0.1881,0.2641,0.1897,0.2147,0.1711,0.2214,0.1733,0.1506,0.1828,0.1537,0.1865,0.1300,0.1305,0.1106,0.1101,0.1557,0.1288,0.1543,0.0978,0.1012,0.0870,0.0942,0.1069,0.1150,0.1193,0.2526,0.0914,0.0941,0.0937,0.0805]

# %% [markdown]
# 1000 labels --- 30 epochs ---Colorize(100)-100 epochs -- seed = 1

# %%
shake_wrn = []0.0928,0.0838,0.0950,0.0736,0.0848,0.0804,0.0820,0.0965,0.0872,0.0882,0.0750,0.0834,0.0749,0.0787,0.0766,0.0799,0.0761,0.0864,0.0834,0.0817,0.0949,0.0787,0.0840,0.0896,0.0845,0.0801,0.0799,0.0821,0.0866,0.0755

# %% [markdown]
# # 500labels

# %% [markdown]
# Affine + Move Model 1

# %% [markdown]
# 500 labels --- 30 epochs ---Colorize(100)-100 epochs -- seed = 1

# %%
shake_wrn = []

# %% [markdown]
# 500 labels --- 30 epochs ---Colorize-300 epochs -- seed = 1

# %%
shake_wrn = [0.1463,0.1363,0.1152,0.1049,0.0980,0.0959,0.1245,0.1023,0.1215,0.0868,0.0916,0.0783,0.0837,0.0847,0.1063,0.1081,0.0868,0.1038,0.0796,0.1066,0.0957,0.0778,0.1324,0.1013,0.0756,0.0653,0.0925,0.0665,0.0666,0.0593]
wrn = ? [0.3090,0.1371,0.2539,0.2432,0.2699,0.3356,0.3065,0.3919,0.3998,0.4635,0.3491,0.2192,0.4507,0.3211,0.3741,0.3516,0.6038,0.4592,0.4042,0.3793,0.5753,0.4418,0.5820,0.3541,0.4184,0.3664,0.5490,0.5192,0.4348,0.1741]
convnet = ? [0.1867,0.2780,0.3185,0.3914,0.2897,0.2769,0.4123,0.2808,0.4684,0.5423,0.2432,0.4519,0.3376,0.4950,0.3738,0.4166,0.5033,0.3637,0.5216,0.3640,0.4324,0.4238,0.3980,0.4052,0.5346,0.4221,0.6383,0.6505,0.5219,0.5219]

# %% [markdown]
# 500 labels --- 20 epochs ---Colorize-100 epochs -- seed = 1

# %%
shake_wrn = [0.1456,0.1151,0.1075,0.0948,0.0994,0.0970,0.1143,0.1051,0.1091,0.0890,0.0919,0.0889,0.0884,0.0774,0.0930,0.0815,0.0725,0.0797,0.0721,0.0656]
wrn = [0.1724,0.1664,0.2004,0.1252,0.1708,0.2197,0.1668,0.1994,0.2289,0.2258,0.1303,0.1597,0.1071,0.1636,0.1137,0.1129,0.1870,0.1514,0.1423,0.0820]
convnet = ? [0.2438,0.2019,0.2312,0.2041,0.2472,0.2077,0.3476,0.3776,0.4170,0.4652,0.3727,0.4850,0.4913,0.3591,0.4646,0.6238,0.5691,0.4356,0.5659,0.5105]

# %% [markdown]
# 500 labels --- 30 epochs ---Colorize-100 epochs

# %%
shake_wrn = [0.1551,0.1154,0.1060,0.1103,0.0972,0.0979,0.0918,0.1017,0.1048,0.1067,0.0815,0.0930,0.0892,0.1023,0.0814,0.0788,0.0844,0.1036,0.0834,0.0880,0.0753,0.0700,0.0858,0.0734,0.0761,0.0711,0.0776,0.0718,0.0680,0.0618]
wrn = [0.2736,0.1671,0.1523,0.2920,0.1743,0.2060,0.1474,0.1761,0.1272,0.1676,0.1452,0.1420,0.2657,0.1593,0.1217,0.1156,0.1282,0.1590,0.1343,0.1109,0.1078,0.1373,0.1155,0.1057,0.1183,0.0928,0.1049,0.1058,0.1003,0.0783]
convnet = ? [0.1608,0.2062,0.2535,0.2922,0.2588,0.4269,0.3313,0.3334,0.1433,0.4279,0.2764,0.5764,0.4710,0.3723,0.5124,0.1462,0.6157,0.5079,0.5525,0.5584,0.5153,0.4104,0.5018,0.5081,0.5834,0.5385,0.6108,0.5945,0.5795,0.5933]

# %% [markdown]
# 500 labels --- 30 epochs ---Colorize-200 epochs

# %%
shake_wrn = [0.1416,0.1104,0.1253,0.1183,0.0935,0.1006,0.0826,0.1169,0.0978,0.0842,0.0995,0.0804,0.0866,0.0779,0.0853,0.0810,0.0829,0.0843,0.0859,0.0873,0.0749,0.0939,0.0799,0.0728,0.0832,0.0729,0.0804,0.0787,0.0713,0.0637]
wrn =       [0.2691,0.1957,0.2544,0.3416,0.1715,0.1969,0.3260,0.2613,0.4488,0.4136,0.3672,0.5020,0.4452,0.1772,0.4679,0.4687,0.3697,0.5459,0.5201,0.5298,0.5572,0.4725,0.4694,0.4513,0.3084,0.4155,0.1515,0.4136,0.5226,0.4044]
convnet = ？ [0.2089,0.1762,0.2105,0.2346,0.1679,0.3060,0.2673,0.3974,0.4405,0.4922,0.2717,0.4972,0.4394,0.3907,0.1690,0.4873,0.5179,0.2076,0.4453,0.4199,0.3367,0.3633,0.4955,0.5388,0.5464,0.4982,0.1347,0.5115,0.1258,0.4693]
             [0.2089,0.1833,0.1525,0.2011,0.2042,0.2165,0.2180,0.2168,0.3134,0.3108,0.1863,0.1749,0.1875,0.1752,0.1497,0.1701,0.2381,0.4058,0.1536,0.1722,0.1598,0.1852,0.1380,0.1629,0.1102,0.1422,0.1371,0.1374,0.1351,0.1131]

# %% [markdown]
# # 250labels

# %% [markdown]
# 250 labels --- 30 epochs ---Colorize(100)-100 epochs -- seed = 1

# %%
shake_wrn = []

# %% [markdown]
# 250 labels --- 30 epochs ---Colorize-100 epochs

# %%
shake_wrn = [0.2432,0.1638,0.1311,0.1357,0.1335,0.1240,0.1185,0.1263,0.1311,0.1239,0.1068,0.1097,0.1190,0.1086,0.1164,0.1186,0.1052,0.1166,0.1082,0.1116,0.0933,0.1078,0.1071,0.1147,0.1007,0.1059,0.1031,0.0951,0.1146,0.0893]
wrn = ? [0.2641,0.2568,0.3104,0.4100,0.3772,0.2567,0.4327,0.3583,0.4827,0.3577,0.5289,0.4897,0.4065,0.4781,0.4613,0.4693,0.4819,0.3542,0.4820,0.4110,0.3728,0.5506,0.3719,0.4993,0.3857,0.4757,0.4271,0.4787,0.5113,0.3549]
convnet = [,0.5004,0.2399,0.3725,0.2439,0.2228,0.3764,0.4098,0.3424,0.5268,0.2520,0.3057,0.2210,0.2727,0.2434,0.2716,0.5088,0.2689,0.2603,0.1971,0.2165,0.2359,0.2137,0.2548,0.2127,0.2382,0.2189,0.2091,0.2233,0.2289,0.2009]

# %% [markdown]
# 250 labels --- 30 epochs ---Colorize-200 epochs

# %%
shake_wrn = [0.2507,0.1744,0.1478,0.1444,0.1412,0.1656,0.1411,0.1139,0.1316,0.1390,0.1236,0.1295,0.1468,0.1234,0.1305,0.1362,0.1249,0.1700,0.1329,0.1438,0.1479,0.1677,0.1458,0.1676,0.1266,0.1071,0.1325,0.1460,0.1210,0.1297]
convnet =   [0.2561,0.3949,0.3374,0.3904,0.2391,0.3544,0.2493,0.3738,0.2903,0.2554,0.4261,0.2576,0.2719,0.4595,0.2404,0.2054,0.2065,0.2262,0.2592,0.2047,0.1948,0.2837,0.2433,0.2346,0.2798,0.2188,0.1985,0.2230,0.2008,0.1883]
wrn =       [0.3709,0.2507,0.1806,0.2891,0.2622,0.2801,0.3512,0.3448,0.3366,0.2982,0.5111,0.4675,0.4169,0.5020,0.5046,0.3941,0.5044,0.3197,0.4569,0.3946,0.4745,0.5437,0.3904,0.4478,0.3994,0.1342,0.3999,0.4271,0.4571,0.3841]

# %% [markdown]
# 250 labels --- 30 epochs ---Colorize-300 epochs

# %%
shake_wrn = [0.2278,0.1916,0.1645,0.1408,0.1307,0.1404,0.1279,0.1303,0.1149,0.1283,0.1221,0.1119,0.1305,0.1068,0.1117,0.1136,0.1127,0.1436,0.1269,0.1162,0.1032,0.1214,0.1092,0.0978,0.1001,0.0931,0.0911,0.1060,0.0956,0.0864]
convnet =   [0.3632,0.3990,0.3211,0.3318,0.2746,0.3457,0.2518,0.4930,0.2273,0.2724,0.2816,0.2491,0.2745,0.2229,0.2612,0.2461,0.1961,0.2090,0.2166,0.2094,0.2226,0.2449,0.3596,0.2121,0.4873,0.2251,0.1862,0.2467,0.1854,0.1791]
wrn = ?     [0.3403,0.2672,0.3597,0.1804,0.4594,0.3844,0.3138,0.2986,0.5359,0.5236,0.5669,0.6373,0.5165,0.6181,0.1863,0.6029,0.2372,0.6379,0.6219,0.1907,0.5053,0.6034,0.6255,0.6184,0.1698,0.5366,0.5769,0.5535,0.6360,0.5894]

# %% [markdown]
# # CIFAR100

# %% [markdown]
# # 50000 labels

# %% [markdown]
# CIFAR100--50000-- epochs10--seed=1

# %%
convnet = [0.5612,0.5008,0.4670,0.4550,0.4369,0.4092,0.4206,0.3442,0.3125,0.2578]
wrn =     [0.6808,0.5185,0.5154,0.4568,0.4622,0.4239,0.3812,0.3665,0.3403,0.2701]
resnet50 = [0.9759,0.9362,0.9095,0.9695,0.9116,0.7921,0.7878,0.7533,0.7457,0.6986]
nin =     [0.6412,0.6032,0.4979,0.5187,0.4739,0.4983,0.4191,0.4289,0.3855,0.3002]
vgg16 =   [0.9891,0.9617,0.9114,0.8378,0.9694,0.7166,0.9879,0.6557,0.9396,0.5550]
mobilenet = [0.8572,0.7369,0.6194,0.5581,0.5593,0.5144,0.5241,0.4732,0.4551,0.4333]
shake_wrn = [0.7343,0.6220,0.5838,0.5421,0.5005,0.5102,0.4710,0.4486,0.4202,0.3811]

# %% [markdown]
# CIFAR100--50000-- epochs20--seed=1

# %%
convnet = [0.5551,0.5568,0.5381,0.5050,0.4264,0.4126,0.4200,0.4145,0.3880,0.3646,0.4037,0.3803,0.3519,0.3530,0.3560,0.3431,0.3315,0.2989,0.2950,0.2507]
wrn =     [0.6111,0.4925,0.5567,0.5003,0.4959,0.4572,0.4397,0.4146,0.4285,0.3789,0.3869,0.3895,0.3641,0.3714,0.3578,0.3212,0.3492,0.3259,0.3023,0.2487]
shake_wrn = [0.7460,0.6342,0.5787,0.5464,0.5132,0.4887,0.4676,0.4412,0.4478,0.4246,0.4120,0.4151,0.4034,0.4054,0.3866,0.3699,0.3901,0.3644,0.3603,0.3274]

# %% [markdown]
# CIFAR100--50000-- epochs10--seed=5

# %%
convnet = [0.6564,0.6477,0.4690,0.4915,0.4609,0.4292,0.3871,0.3581,0.3229,0.2561]
nin =     [0.7233,0.5891,0.5114,0.4778,0.5382,0.4323,0.4202,0.4009,0.3981,0.3035]
wrn = []
shake_wrn = []

# %% [markdown]
# CIFAR100--20000-- epochs10--seed=1

# %%
convnet = [0.5871,0.5164,0.5017,0.4476,0.4404,0.4508,0.4424,0.4002,0.3938,0.3307]
wrn =     [0.6398,0.5309,0.5136,0.4696,0.5044,0.4879,0.5068,0.4395,0.4047,0.3443]
nin =     [0.7062,0.5476,0.5601,0.5105,0.5222,0.5079,0.4620,0.4738,0.4443,0.3718]
shake_wrn = [0.7519,0.6504,0.5901,0.5320,0.5190,0.4852,0.4766,0.4587,0.4293,0.4025]

# %% [markdown]
# CIFAR100--20000-- epochs20--seed=1

# %% [markdown]
# CIFAR100--20000-- epochs10--seed=1 -- Affine+Move

# %%
convnet = [0.5993,0.6271,0.5098,0.5490,0.5160,0.6157,0.4801,0.4728,0.5279,0.3606]
wrn =     [0.6447,0.5777,0.5558,0.5159,0.7411,0.4845,0.7017,0.5005,0.4407,0.3566]
nin =     [0.7308,0.5711,0.5663,0.5508,0.5623,0.5296,0.6333,0.4946,0.6166,0.5508]
shake_wrn=[0.7702,0.6411,0.6428,0.5718,0.5515,0.5260,0.5225,0.4697,0.5353,0.4473]

# %% [markdown]
# CIFAR100--20000-- epochs10--seed=1 -- Affine

# %%
convnet = [0.5916,0.5841,0.5886,0.5066,0.4750,0.5638,0.6220,0.5910,0.4720,0.3804]
wrn =     [0.6515,0.5997,0.5043,0.5992,0.6194,0.5830,0.6007,0.6238,0.6134,0.3640]
nin = []

# %% [markdown]
# CIFAR100 -- 50000 labels --- 30 epochs ---Colorize-CIFAR100---100 epochs

# %%
convnet = [0.6569,0.5084,0.4368,0.3924,0.4261,0.3853,0.3887,0.3807,0.3848,0.3889,0.3898,0.3767,0.3680,0.3806,0.3783,0.3820,0.3745,0.3382,0.3360,0.3468,0.3458,0.3762,0.3223,0.3418,0.3307,0.3184,0.3047,0.3102,0.2757,0.2440]
wrn = []
shake_wrn = [0.7170,0.5989,0.5369,0.5047,0.5180,0.4690,0.4573,0.4419,0.4274,0.4222,0.4407,0.4286,0.4214,0.3985,0.4109,0.4075,0.4020,0.3825,0.3778,0.4051,0.3769,0.3680,0.3657,0.3612,0.3618,0.3744,0.3465,0.3370,0.3272,0.3155]

# %% [markdown]
# CIFAR100 -- 50000 labels --- 30 epochs ---Colorize-CIFAR10---100 epochs

# %%
convnet = [0.5367,0.5786,0.4288,0.4233,0.4399,0.4036,0.3953,0.4964,0.3901,0.3979,0.3995,0.3844,0.3356,0.3781,0.3939,0.4216,0.3893,0.4217,0.3406,0.3655,0.3372,0.3371,0.3319,0.3342,0.3271,0.3095,0.3160,0.3007,0.2886,0.2487]
wrn = []
shake_wrn=[]
